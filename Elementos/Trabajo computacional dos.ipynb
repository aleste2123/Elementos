# %%
# %matplotlib notebook
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as anim
from tqdm import tqdm
import sympy as sym 
import random as rand
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from scipy import integrate
from scipy.integrate import odeint

# %% [markdown]
# # 1)

# %%
# MW
x = [300, 350, 400,450,500, 550, 600, 650, 700]
#perdida unitaria 
y = [0.983, 0.982, 0.981, 0.98, 0.978,0.977 , 0.976, 0.974 , 0.973]
# kV
z = [339.26, 338.84, 338.42, 337.99 , 337.54,337.09, 336.62, 336.14, 335.66 ]

plt.scatter(x,y)
plt.xlabel("Ptencia Activa [MW]")
plt.ylabel("Perdidas unitarias")
# Out:
# Text(0, 0.5, 'Perdidas unitarias')

# %%
plt.scatter(x,z)
plt.xlabel("Ptencia Reactiva [MW]")
plt.ylabel("Tenciión de salida [kV]")
# Out:
# Text(0, 0.5, 'Tenciión de salida [kV]')

# %% [markdown]
# # 2)

# %%
# Mvar
x = [100, 150, 200, 250, 300]
#perdida unitaria 
y = [0.978, 0.973,0.968, 0.963, 0.957 ]
# kV
z = [337.54 , 335.73, 333.92, 332.08, 330.22]

plt.scatter(x,y)
plt.xlabel("Potencia Reactiva [MVAr]")
plt.ylabel("Perdidas unitarias")
# Out:
# Text(0, 0.5, 'Perdidas unitarias')

# %%
plt.scatter(x,z)
plt.xlabel("Potencia Reactiva [MVAr]")
plt.ylabel("Tención de salida [kV]")
# Out:
# Text(0, 0.5, 'Tención de salida [kV]')

# %% [markdown]
# 3 )

# %%
# Mvar
x = [-100, -50, 0, 50, 100]
#perdida unitaria 
y = [0.999, 0.994, 0.989, 0.984 , 0.978]
# kV
z = [344.53,342.81, 341.07, 339.31, 337.53]

plt.scatter(x,y)
plt.xlabel("Potencia Reactiva [MVAr]")
plt.ylabel("Perdidas unitarias")
# Out:
# Text(0, 0.5, 'Perdidas unitarias')

# %%
plt.scatter(x,z)
plt.xlabel("Potencia Reactiva [MVAr]")
plt.ylabel("Tención de salida [kV]")
# Out:
# Text(0, 0.5, 'Tención de salida [kV]')

# %% [markdown]
# Las perdidas son de magnetización por la componente imaginaria (Histeresís), y la otra es térmica por las perdidas de Eddy

# %%
#salida mW
def eficiencia(salida, entrada):
    return (salida/entrada)*100

# %% [markdown]
# # Parte 2

# %% [markdown]
# a) Variamos el tab para que tengamos un valor de (en 300MVAr, 500 MW)
#
# pu = 0.999
#
# tab = 1.04375
#
# V = 344.66 kV

# %% [markdown]
# b) Variamos el tab poniendolo en -300MVAr, 500 MW
#
# pu = 0.999
#
# tab = 0.98125
#
# V = 344.67 kV

# %% [markdown]
# # Parte 3

# %% [markdown]
# 1) Tipo de conexión: YY0, resistivo, (desfase 0)
# 2) Tipo de conexión: YD3, Resistico, (Desfase 60 )
# 3) Tipo de conexión: YD, Resistico, (Desfase -30)
